# %%
print("hola soy un code de jupyter notebook jaja xd")
# Out:
# hola soy un code de jupyter notebook jaja xd

# %% [markdown]
# Y yo soy un markdown jaja que cool

# %%
import matplotlib.pyplot as plt
x=[1,2,3,4,5]
y=[2,3,4,6,5]
plt.scatter(x,y)
